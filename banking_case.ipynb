# %% [markdown]
# # welcome to the eda of my data analytic project

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/ASUS/Desktop/Banking.csv")

# %%
df.head(10)
# Out:
#   Client ID               Name  Age  Location ID Joined Bank  \
# 0  IND81288      Raymond Mills   24        34324  06-05-2019
# 1  IND65833      Julia Spencer   23        42205  10-12-2001
# 2  IND47499     Stephen Murray   27         7314  25-01-2010
# 3  IND72498     Virginia Garza   40        34594  28-03-2019
# 4  IND60181    Melissa Sanders   46        41269  20-07-2012
# 5  IND78532      Samuel Hudson   23        13204  07-02-2019
# 6  IND95683  Timothy Alexander   46        42910  02-06-2002
# 7  IND40785        Carl Martin   78         6127  03-11-2000
# 8  IND13570         Philip Day   67        32656  07-04-2015
# 9  IND53299         Jason Sims   51        28340  20-11-1995
#
#     Banking Contact Nationality                 Occupation Fee Structure  \
# 0    Anthony Torres    American       Safety Technician IV          High
# 1  Jonathan Hawkins     African        Software Consultant          High
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Client ID                 3000 non-null   object
#  1   Name                      3000 non-null   object
#  2   Age                       3000 non-null   int64
#  3   Location ID               3000 non-null   int64
#  4   Joined Bank               3000 non-null   object
#  5   Banking Contact           3000 non-null   object
#  6   Nationality               3000 non-null   object
#  7   Occupation                3000 non-null   object
#  8   Fee Structure             3000 non-null   object
#  9   Loyalty Classification    3000 non-null   object
#  10  Estimated Income          3000 non-null   float64
#  11  Superannuation Savings    3000 non-null   float64
#  12  Amount of Credit Cards    3000 non-null   int64
# ...

# %%
df.describe(include='all')
# Out:
#        Client ID              Name          Age   Location ID Joined Bank  \
# count       3000              3000  3000.000000   3000.000000        3000
# unique      2940              2913          NaN           NaN        2579
# top     IND48103  Jeremy Alexander          NaN           NaN  19-06-2020
# freq           3                 2          NaN           NaN           4
# mean         NaN               NaN    51.039667  21563.323000         NaN
# std          NaN               NaN    19.854760  12462.273017         NaN
# min          NaN               NaN    17.000000     12.000000         NaN
# 25%          NaN               NaN    34.000000  10803.500000         NaN
# 50%          NaN               NaN    51.000000  21129.500000         NaN
# 75%          NaN               NaN    69.000000  32054.500000         NaN
# max          NaN               NaN    85.000000  43369.000000         NaN
#
#        Banking Contact Nationality           Occupation Fee Structure  \
# ...

# %%
df.isnull().sum()
# Out:
# Client ID                   0
# Name                        0
# Age                         0
# Location ID                 0
# Joined Bank                 0
# Banking Contact             0
# Nationality                 0
# Occupation                  0
# Fee Structure               0
# Loyalty Classification      0
# Estimated Income            0
# Superannuation Savings      0
# Amount of Credit Cards      0
# Credit Card Balance         0
# Bank Loans                  0
# Bank Deposits               0
# Checking Accounts           0
# Saving Accounts             0
# Foreign Currency Account    0
# Business Lending            0
# Properties Owned            0
# Risk Weighting              0
# BRId                        0
# GenderId                    0
# IAId                        0
# dtype: int64

# %%
df.columns=df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['client id', 'name', 'age', 'location id', 'joined bank',
#        'banking contact', 'nationality', 'occupation', 'fee structure',
#        'loyalty classification', 'estimated income', 'superannuation savings',
#        'amount of credit cards', 'credit card balance', 'bank loans',
#        'bank deposits', 'checking accounts', 'saving accounts',
#        'foreign currency account', 'business lending', 'properties owned',
#        'risk weighting', 'brid', 'genderid', 'iaid'],
#       dtype='object')

# %%
df.columns=df.columns.str.replace(" ","_")

# %%
df.columns
# Out:
# Index(['client_id', 'name', 'age', 'location_id', 'joined_bank',
#        'banking_contact', 'nationality', 'occupation', 'fee_structure',
#        'loyalty_classification', 'estimated_income', 'superannuation_savings',
#        'amount_of_credit_cards', 'credit_card_balance', 'bank_loans',
#        'bank_deposits', 'checking_accounts', 'saving_accounts',
#        'foreign_currency_account', 'business_lending', 'properties_owned',
#        'risk_weighting', 'brid', 'genderid', 'iaid'],
#       dtype='object')

# %%
df['genderid']
# Out:
# 0       1
# 1       1
# 2       2
# 3       1
# 4       2
#        ..
# 2995    2
# 2996    2
# 2997    2
# 2998    2
# 2999    2
# Name: genderid, Length: 3000, dtype: int64

# %%
df['gender']=df['genderid'].apply(lambda x:'male' if x==1 else 'female')

# %%
df['gender']
# Out:
# 0         male
# 1         male
# 2       female
# 3         male
# 4       female
#          ...
# 2995    female
# 2996    female
# 2997    female
# 2998    female
# 2999    female
# Name: gender, Length: 3000, dtype: object

# %%
df.drop('genderid',axis=1)
# Out:
#      client_id              name  age  location_id joined_bank  \
# 0     IND81288     Raymond Mills   24        34324  06-05-2019
# 1     IND65833     Julia Spencer   23        42205  10-12-2001
# 2     IND47499    Stephen Murray   27         7314  25-01-2010
# 3     IND72498    Virginia Garza   40        34594  28-03-2019
# 4     IND60181   Melissa Sanders   46        41269  20-07-2012
# ...        ...               ...  ...          ...         ...
# 2995  IND66827         Earl Hall   82         8760  09-10-2014
# 2996  IND40556  Billy Williamson   44        32837  05-02-2009
# 2997  IND72414      Victor Black   70        36088  29-12-2009
# 2998  IND46652       Andrew Ford   56        24871  13-02-2006
# 2999  IND40216        Amy Nguyen   79        38518  08-12-2005
#
#           banking_contact nationality                     occupation  \
# 0          Anthony Torres    American           Safety Technician IV
# ...

# %%
df.drop('bank_type',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 df.drop('bank_type',axis=1)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
#    5593         level=level,
#    5594         inplace=inplace,
#    5595         errors=errors,
#    5596     )
#
# ...

# %%
df.columns

# %%
df['bank_type']=df['brid'].replace(lambda x:'retail' if x==1 else 'institutional' if x==2 else 'public' if x==3 else 'commnercial' if x==4

# %%
df['bank_type'] = df['brid'].map({
    1: 'retail',
    2: 'institutional',
    3: 'public',
    4: 'commercial'
}).fillna('unknown')

# %%
df.head()

# %%
df['investment_advisor'] = df['iaid'].map({    1:'Victor Dean',
2:	'Jeremy Porter',
3:	'Ernest Knight',
4:	'Eric Shaw',
5:	'Kevin Kim',
6:	'Victor Rogers',
7:	'Eugene Cunningham',
8:	'Joe Carroll',
9:	'Steve Sanchez',
10:	'Lawrence Sanchez',
11:	'Peter Castillo',
12:	'Victor Gutierrez',
13:	'Daniel Carroll',
14:	'Carl Anderson',
15:	'Nicholas Ward',
16:	'Fred Bryant',
17:	'Ryan Taylor',
18:	'Sean Vasquez',
19:	'Nicholas Morrison',
20:	'Jack Phillips',
21:	'Juan Ramirez',
22:	'Gregory Boyd'

}).fillna('unknown')

# %%
df.columns

# %%
df['estimated_income'].value_counts()

# %%
bins=[0,100000,300000,float("inf")]
labels=['low','med','high']
df['income_band']=pd.cut(df['estimated_income'],bins=bins,labels=labels,right=False)

# %%
df['income_band']
# Out:
# 0        low
# 1        med
# 2        med
# 3       high
# 4        med
#         ...
# 2995     med
# 2996     low
# 2997     low
# 2998     med
# 2999     low
# Name: income_band, Length: 3000, dtype: category
# Categories (3, object): ['low' < 'med' < 'high']

# %%
df['income_band'].value_counts().plot(kind='bar')

# %%
df['gender'].value_counts().plot(kind='bar')
plt.show()

df['bank_type'].value_counts().plot(kind='bar')
plt.show()

# %%
for i,predictor in enumerate(df['brid','gender','iaid','amount_of_credit_cards','nationality','occupation','fee_structure','loyal_classification']):
    plt.figure(i)
    sns.countplot(data=df,x=predictor,hue='gender_id')

# %%
columns = ['brid', 'gender', 'iaid', 'amount_of_credit_card',
           'nationality', 'occupation', 'fee_structure', 'loyal_classification']

for i, predictor in enumerate(columns):
    sns.countplot(data=df, x=predictor, hue='genderid')

# %%
df

# %%
for i, predictor in enumerate(df[["brid", "genderid", "iaid", "amount_of_credit_cards", "nationality", "occupation", "fee_structure", "loyalty_classification", "properties_owned", "risk_weighting", "income_band"]].columns):
    plt.figure(i)
    sns.countplot(data=df, x=predictor)

# %%
from sqlalchemy import create_engine, text
from urllib.parse import quote_plus

username = "root"
password = quote_plus("1989211ss@V")
host = "localhost"
port = "3306"

# connect to MySQL server (no database yet)
engine = create_engine(f"mysql+pymysql://{username}:{password}@{host}:{port}")

# %%
with engine.connect() as conn:
    conn.execute(text("CREATE DATABASE IF NOT EXISTS mydata;"))

# %%
database = "mydata"
engine = create_engine(f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}")

# %%
df.to_sql("mytable", engine, if_exists="replace", index=False)

import pandas as pd
result = pd.read_sql("SELECT * FROM mytable LIMIT 5;", engine)

print(result)

# %%
df.columns
# Out:
# Index(['client_id', 'name', 'age', 'location_id', 'joined_bank',
#        'banking_contact', 'nationality', 'occupation', 'fee_structure',
#        'loyalty_classification', 'estimated_income', 'superannuation_savings',
#        'amount_of_credit_cards', 'credit_card_balance', 'bank_loans',
#        'bank_deposits', 'checking_accounts', 'saving_accounts',
#        'foreign_currency_account', 'business_lending', 'properties_owned',
#        'risk_weighting', 'brid', 'genderid', 'iaid', 'gender'],
#       dtype='object')
